# %% [markdown]
# # Self-Balancing Scooter Control
#
# ![](images/self-balancing-scooter.png)
#
# > A self-balancing scooter [...] is a self-balancing personal transporter consisting of two motorized wheels connected to a pair of articulated pads on which the rider places their feet. The rider controls the speed by leaning forward or backward, and direction of travel by twisting the pads.
# >
# > Source: <https://en.wikipedia.org/wiki/Self-balancing_scooter>

# %% [markdown]
# ### Python Dependencies

# %%
from numpy import *
from numpy.linalg import *

from scipy.linalg import *
from scipy.integrate import *
from scipy.signal import *

from matplotlib.pyplot import *

# %% [markdown]
# Step 1 - Scooter Planar Model
# ================================

# %% [markdown]
# ### Introduction

# %% [markdown]
# We consider a simple model of a self-balancing scooter evolving in the plane. It is mainly made of
#
#   - The frame that contains the two articulated pads; from above, each pad essentially look like a triangle (one vertice in the center of the frame, one vertice at each extremity of the wheel).
#
#   - Two fixed wheels (their orientation with respect to the frame does not change).
#     They are parallel and located at opposite ends of the frame.
#
# Let $(0, e_x, e_y)$ be a direct orthonormal frame of the plane. We denote
#
#   - $(x, y)$ the coordinates of the wheel axis center in the orthonormal and
#   - $\theta$ the angle of the wheels direction with respect to vector $e_x$ ; with $\theta = 0$ when the front of the scooter faces the right ($e_x$) and $\theta = \pi/2$ when it faces upwards ($e_y$).
#
#   - $\phi_l$ and $\phi_r$ the rotation angles of the left and right wheel respectively ; by convention, when these angles increase, the scooter moves forward.

# %% [markdown]
# ### Parameter Definition

# %% [markdown]
# From now on, we assume that the seat frame length is $\ell = 50 \mbox{ cm}$ and the wheel radius is $r = 12.5 \mbox{ cm}$.
#
# 🧩 Define the corresponding Python variables `l` and `r` (express every length in meters, and more generally in the sequel, always use the [international standard of units](https://en.wikipedia.org/wiki/SI_derived_unit)) for numerical values.

# %%
# 🔓
l = 50 / 100
r = 12.5 / 100

# %% [markdown]
# ### Graphical Representation
#
# 🧩 Implement a function `draw_scooter` with arguments `x`, `y` and `theta` that draws a simple geometric model of the scooter (with a red frame and black fixed wheels) in the plane (top view) for arbitrary values of $(x, y)$ and $\theta$. Use a green circle marker 50 cm in of the frame to indicate which way is forward.
#
# 🗝️ **Hint.** Use the function `plot` of `matplotlib.pyplot`.

# %%
# 🔓
def draw_scooter(x, y, theta):
    translation = array([[x], [y]])
    rotation = array([
        [cos(theta), -sin(theta)], 
        [sin(theta),  cos(theta)]
    ])

    # Left pad
    corners = [[0, 0], [-r, l/2], [r, l/2]]
    corners += [corners[0]]
    corners = array(corners).T
    corners = rotation @ corners + translation
    xc = corners[0]
    yc = corners[1]
    fill(xc, yc, color="red", zorder=10)

    # Right pad
    corners = [[0, 0], [r, -l/2], [-r, -l/2]]
    corners += [corners[0]]
    corners = array(corners).T
    corners = rotation @ corners + translation
    xc = corners[0]
    yc = corners[1]
    fill(xc, yc, color="red", zorder=10)
    
    # Fixed Wheels
    wheel_left_xy_start = rotation @ [[-r], [-l/2]] + translation 
    wheel_left_xy_end = rotation @ [[r], [-l/2]] + translation
    plot([wheel_left_xy_start[0], wheel_left_xy_end[0]], [wheel_left_xy_start[1], wheel_left_xy_end[1]], color="black",linewidth=5, zorder=20)

    wheel_right_xy_start = rotation @ [[-r], [l/2]] + translation
    wheel_right_xy_end = rotation @ [[r], [l/2]] + translation
    plot([wheel_right_xy_start[0], wheel_right_xy_end[0]], [wheel_right_xy_start[1], wheel_right_xy_end[1]], color="black", linewidth=5, zorder=20)

    # Forward marker
    xm, ym = rotation @ array([0.5, 0]) + array([x, y])
    plot([xm], [ym], "o", color="green")

# %% [markdown]
# 🧩 Represent the scooter when $(x, y, \theta) = (0, 0, 0), (2, 2, \pi/2), (0, 4, \pi), (-2, 2, 3\pi/2)$.
#
# 🗝️ **Hint.** Use the following `draw_arena` function beforehand.

# %%
def draw_arena(xmin, xmax, ymin, ymax):
    wh_ratio = (xmax - xmin) / (ymax - ymin)
    figsize = fig_width, fig_height = 16, 16 / wh_ratio
    figure(figsize=figsize)
    axes = gca()
    axes.axis([xmin, xmax, ymin, ymax])
    axes.set_aspect(1)
    xticks(arange(xmin, xmax+1, 1))
    yticks(arange(ymin, ymax+1, 1))
    grid(True)

# %%
# 🔓
draw_arena(-5, 5, -1, 5)
draw_scooter(0, 0, 0)
draw_scooter(2, 2, pi/2)
draw_scooter(0, 4, pi)
draw_scooter(-2, 2, 3*pi/2)

# %% [markdown]
# ### Kinematic Modeling
#
# We assume that we can control the wheels angular velocities $\omega_l = \dot{\phi}_l$ and $\omega_r = \dot{\phi}_r$ (this is a *kinematic* model of the scooter).
# We also assume that the scooter fixed wheels roll without slipping.
#
# 🧩 Establish the differential equations that relate $\dot{x}$,
# $\dot{y}$ and $\dot{\theta}$ with $\omega_l$ and $\omega_r$.

# %% [markdown]
# 🔓
# $$
# \begin{array}{rcl}
# \dot{x} &=& r  \frac{\omega_l + \omega_r}{2} \cos \theta \\
# \dot{y} &=& r  \frac{\omega_l + \omega_r}{2} \sin \theta \\
# \dot{\theta} &=& r  \frac{\omega_r - \omega_l}{\ell} \\
# \end{array}
# $$

# %% [markdown]
# ### Analysis
#
# 🧩 Show that if $\omega_l$ and $\omega_r$ are continuously differentiable functions of $(x, y, \theta)$ (which includes the case of constant inputs), this system is well-posed.

# %% [markdown]
# 🔓 The vector field is continuously differentiable as a composition of continuously differentiable functions, thus the IVP is well-posed.

# %% [markdown]
# 🧩 Show that if $\omega_l$ and $\omega_r$ are constants, the maximal solution associated to any initial state is global. Is is still true of $\omega_l$ and $\omega_r$ are arbitrary continuously differentiable functions of $(x, y, \theta)$ ?

# %% [markdown]
# 🔓 When the inputs are constant, it's pretty easy to prove that the derivatives of $x$, $y$ and $\theta$ with respect to $t$ are uniformly bounded ; thus $x$, $y$ and $\theta$ are bounded on any bounded time interval and therefore no finite-time blowup may happen: the maximal solution is global.
#
# The situation is different with state-dependent inputs; for example with $\omega_r = - \omega_l = 0.5 (\ell/r)  \theta^2$, we end up with $\dot{\theta}(t) = \theta(t)^2$ which has a finite-time blowup for some initial values of $\theta$. Thus, the maximal solution may not be global.

# %% [markdown]
# ### Vector Field
#
# In the sequel, `omega` is a function that computes the input vector $\omega := (\omega_l, \omega_r)$ given the time $t$ and $(x, y, \theta)$ (thus, it may depend on the time and/or on the system state if needed). For example:

# %%
def omega(t, xytheta):
    omega_l = (1 - l/4) * pi / r
    omega_r = (1 + l/4) * pi / r
    return array([omega_l, omega_r])

# %% [markdown]
# 🧩 Implement a function `fun(t, xytheta)` that computes $(\dot{x}, \dot{y}, \dot{\theta})$ given the time $t$ and $(x,y,\theta)$ (and implicitly the inputs $\omega$ computed by the function `omega`).

# %%
# 🔓
def fun(t, xytheta):
    x, y, theta = xytheta
    omega_l, omega_r = omega(t, xytheta)
    dx = r * 0.5 * (omega_l + omega_r) * cos(theta)
    dy = r * 0.5 * (omega_l + omega_r) * sin(theta)
    dtheta = r * (omega_r - omega_l) / l
    return array([dx, dy, dtheta])

# %% [markdown]
# ### Simulation Setup
#
# 🧩 Simulate the scooter dynamics for 4 seconds when $(x_0, y_0, \theta_0)(t=0) = (0.0, 0.0, 0.0)$,
# and the wheels velocities are the constants $\omega_l = (1 - \ell/4)  \pi / r \mbox{ rad/s}$ and $\omega_r = (1 + \ell/4)  \pi / r \mbox{ rad/s}$.
# (Compute the dense outputs.)

# %%
# 🔓
results = solve_ivp(fun=fun, t_span =(0.0, 4.0), y0=[0.0, 0.0, 0.0], dense_output=True)

# %% [markdown]
# 🧩 Use the simulation results to draw the graphs of $x(t)$, $y(t)$ and $\theta(t)$.

# %%
# 🔓
t = linspace(0.0, 4.0, 1000)
x, y, theta = results["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, x, label="$x(t)$")
ax1.plot(t, y, label="$y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta, label=r"$\theta(t)$", color="C2")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# 🧩 Use the simulation results to display the robot location every 0.5 second.

# %%
# 🔓
t = linspace(0.0, 4.0, 4*2+1)
sol_t = results["sol"](t)
draw_arena(-4, 4, -1, 5)
for x, y, theta in sol_t.T:
    draw_scooter(x, y, theta)

# %% [markdown]
# 🧩 What should be the analytical expression of $x(t)$, $y(t)$ and $\theta(t)$?

# %% [markdown]
# $\theta(t) = 2 \pi / 4.0$, $x(t) = 2\sin(2\pi t / 4)$ and $y(t) = -2 \cos(2\pi t / 4)+2$.

# %% [markdown]
# 🧩 Do you experimental results match the theoretical results ? Draw the curves of the simulation error at time $t$ for $x$, $y$ and $\theta$.

# %%
t = linspace(0.0, 4.0, 1000)
x_t, y_t, theta_t = results["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t , x_t - 2*sin(2*pi*t/4), label="$x(t)$ error")
ax1.plot(t , y_t + 2*cos(2*pi*t/4) - 2, label="$y(t)$ error")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta_t - 2*pi*t / 4.0, label=r"$\theta(t)$ error")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# 🧩 If needed, adjust the simulation parameters the simulated position error is less than $1\, \mathrm{ mm}$.

# %%
results = solve_ivp(
    fun=fun, 
    t_span=(0.0, 4.0), 
    y0=[0.0, 0.0, 0.0], 
    rtol=1e-6, 
    atol=1e-6, 
    dense_output=True
)
t = linspace(0.0, 4.0, 1000)
x_t, y_t, theta_t = results["sol"](t)
figure(figsize=(15, 15))
grid(True)
plot(t , sqrt((x_t - 2*sin(2*pi*t/4))**2 + (y_t + 2*cos(2*pi*t/4) - 2)**2) , label="$(x(t), y(t))$ error")
legend()
grid(True)
xlabel("time")
pass

# %% [markdown]
# Step 2 - Control Implementation
# ===============================

# %% [markdown]
# Time dependent inputs
# ---------------------

# %% [markdown]
# We are going to simulate the case of the scooter controlled by time-dependent angular velocities $\omega_l$ and $\omega_r$.
# We want a simulation lasting 5 seconds with the following inputs:
# $$
#     \omega_l(t) = \left\{
#        \begin{array}{rl}
#            (1 - \ell/4) \pi / r & \mbox{when $t \leq 1 \,  \mathrm{s}$ or  $t \geq 3 \,  \mathrm{s}$,} \\
#            (1 + \ell/4) \pi / r & \mbox{otherwise.}
#        \end{array}
#     \right.
# $$
# and
# $$
#     \omega_r(t) = \left\{
#        \begin{array}{rl}
#            (1 + \ell/4) \pi / r & \mbox{when $t \leq 1 \,  \mathrm{s}$ or $t \geq 3 \,  \mathrm{s}$,} \\
#            (1 - \ell/4) \pi / r & \mbox{otherwise.}
#        \end{array}
#     \right.
# $$

# %% [markdown]
# ##### 🧩 Provide the new definition of `omega`

# %%
# 🔓
def omega(t, xytheta):
    if t <= 1 or t >= 3:
        omega_l = (1 - l/4) * pi / r
        omega_r = (1 + l/4) * pi / r
    else:
        omega_l = (1 + l/4) * pi / r
        omega_r = (1 - l/4) * pi / r
    return array([omega_l, omega_r])

# %% [markdown]
# ##### 🧩 Make a simulation of 4 sec of the robot with the previous input. Use the `rtol` and `atol` that used to guarantee a precision of $1 \, \mathrm{mm}$ and by using the `dense_output` option to evaluate the solution at timesteps that will be defined later.
#
# 🗝️ **Hint.** It is not necessary to define again the function `fun`. If the previous cell has been correctly validated, `fun` will use the new definition of `omega`.

# %%
# 🔓
tf = 4
results = solve_ivp(fun=fun, y0=[0,0,0], t_span=[0,tf], rtol=1e-6, atol=1e-6, dense_output=True)

# %% [markdown]
# 🧩 Use the simulation results to display the robot location every 0.5 seconds.

# %%
# 🔓
step = 0.5
t = arange(0,tf+step,step)
sol_t = results["sol"](t)
draw_arena(-1, 9, -1, 5)
for x, y, theta in sol_t.T:
    draw_scooter(x, y, theta)

# %% [markdown]
# ## Analysis of the system at rest

# %% [markdown]
# ### Equilibrium

# %% [markdown]
# ##### 🧩 Show that for a suitable (constant) choice $\omega_e \in \mathbb{R}^2$ of the vector input $\omega$, the state $X_e = (x_e, y_e, \theta_e) = (0,0,0)$ is an equilibrium of the scooter kinematic model.

# %% [markdown]
# 🔓 **Answer.** If $\omega_e=(0,0)$, $f(X_e)=0$ ($X_e=(0,0,0)$), and so $X_e$ is an equilibrium.

# %% [markdown]
# ##### 🧩 Show that for any other $\omega_e$, the system has no equilibrium.

# %% [markdown]
# 🔓 **Answer.** If $\omega_l\neq 0$ or $\omega_l\neq 0$, two cases:
#
#   1. $\omega_l\neq-\omega_r$ which is different from zero, thus $\dot{x}=\dot{y}=0$ implies $\cos\theta=\sin\theta=0$ which is impossible.
#   2. $\omega_l=-\omega_r$ which is different from zero, thus $\dot{\theta} = 2\omega_r\frac{\ell}{r} \neq 0$
#
# So, there is no equilibrium if $\omega \neq \omega_e$

# %% [markdown]
# ##### 🧩 Conversely, if $\omega = \omega_e$, what are the other equilibria of the system?

# %% [markdown]
# 🔓 **Answer.** If $\omega=\omega_e$, then $\forall X\in\mathbb{R}^3,f(X) = 0$. Every position is an equilibrium (actually, the system is at rest)

# %% [markdown]
# ### Linearized System Model
#
#
# Let $\omega = \omega_e$ and $X_e = (0,0,0)$. Let us introduce the the error variable $\Delta X = (\Delta x, \Delta y, \Delta \theta) = X - X_e$ and $\Delta \omega = \omega - \omega_e$.

# %% [markdown]
# ##### 🧩 Compute the corresponding linearized dynamics and put it in standard form: compute the matrices $A$ and $B$ (remember that $\omega = (\omega_l,\omega_r)$).

# %% [markdown]
# 🔓 **Answer.**
#
# $$
# A= \begin{bmatrix} 0 & 0 &0 \\ 0 & 0 &0 \\ 0 & 0 & 0\end{bmatrix}
# $$
# and
# $$
# B= \begin{bmatrix} \frac{r}{2} & \frac{r}{2}  \\ 0 & 0 \\ -\frac{r}{\ell} & \frac{r}{\ell} \end{bmatrix}
# $$

# %% [markdown]
# ### Stability of the linearized system

# %% [markdown]
# ##### 🧩 Is the linearized system asymptotically stable around $(0,0,0)$ when $\Delta \omega = (0,0)$ ?

# %% [markdown]
# 🔓 **Answer.** No, with the chosen $\Delta \omega$, we have $\dot X = AX$ and $A$ has three null eigenvalues. To have a positive answer, we expected each eigenvalue to have a strictly negative real part.

# %% [markdown]
# ##### 🧩 Is the original system asymptotically stable ? Or even (locally) attractive ?

# %% [markdown]
# 🔓 **Answer.** With $\omega = \omega_e$, the system cannot "move". If $X(t_0) = X_0$, then $\forall t>0, X(t) =X_0$. Thus, if $X_0\neq (0,0,0)$, $X(t)$ does not converge to the origin: the original system is not (even locally) attractive.
#
# As a consequence, it is not asymptotically stable.

# %% [markdown]
# ### Controllability of the linearized system

# %% [markdown]
# In this section, we consider only the linearized system defined by the matrices $A$ and $B$ computed previously:
#
# $$
# \frac{\Delta X}{dt} = A \Delta X + B\Delta u
# $$

# %% [markdown]
# ##### 🧩 Is there an admissible trajectory that start with the state $X_0=(-2,0,0)$ and ends at origin after some time?

# %% [markdown]
# 🔓 **Answer.** Yes, with $\omega \propto (1,1)$, the scooter will move in straight line on the (Ox) axis and will reach the origin after some time depending on the speed.

# %% [markdown]
# ##### 🧩 Is there an admissible trajectory that start with the state $X_0=(0,2,0)$ and ends at origin after some time?

# %% [markdown]
# 🔓 **Answer.** No. According to $A$ and $B$, we have $d{\Delta y}/dt=0$ and so, the error on $y$ cannot be changed by $u$.

# %% [markdown]
# ##### 🧩 Is the linearized system controllable?

# %% [markdown]
# 🔓 **Answer.** No, 2 possible proofs:
#
# 1. Kalman criteria: the controllability matrix has the same rank of $B$ (since $A =0$) which is 2.
#
# 2. We found that some points are not reachable with specific initial condition.

# %% [markdown]
# ## Control on a straight line
#
# ### Admissible trajectories

# %% [markdown]
# Let $x_R(t) = v t$ and $y_R(t) = 0$ where $v \in \mathbb{R}$ and $v \neq 0$.

# %% [markdown]
# ##### 🧩 Determine the set of trajectories $X_R(t) = (x_R(t), y_R(t), \theta_R(t))$ which are admissible and compute the corresponding reference control $\omega_{R}(t)$.

# %% [markdown]
# 🔓 **Answer.** $y_R(t) = 0 \Rightarrow$ $\sin\theta_R = 0$ or $(\omega_l+\omega_r)/2 = 0$. The second case leads to $\dot{x}=0$ which is in contradiction with $\dot x_R = v$.
# Thus, $\theta_R(t) = k\pi$. By continuity ($\theta$ cannot jump from $k\pi$ to $k'\pi$), this defines several sets of solutions in which $\theta_R(t)$ is constant and equal to $k\pi$. This leads to $\dot\theta=0$ and so $\omega_l(t)=\omega_r(t)=\omega(t)$
#
# Finally, $\dot x = r \omega(t)\cos k\pi$.
#
# We have actually 2 true sets of solutions (all the other sets will lead to the same control):
#
# 1. $X_R(t) = (vt ,0, 0)$ with a reference control $\omega_R(t)=(+v/r,+v/r)$
# 1. $X_R(t) = (vt ,0, \pi)$ with a reference control $\omega_R(t)=(-v/r,-v/r)$.

# %% [markdown]
# ### Linearized system

# %% [markdown]
# Let $\Delta X(t) = X(t) - X_R(t)$ and $\Delta \omega(t) = \omega(t) - \omega_R(t)$.

# %% [markdown]
# ##### 🧩 Compute the linearized dynamics of the system for the class of trajectory "moving forward".

# %% [markdown]
# 🔓 **Answer.**
#
# $$
#   A = \begin{bmatrix}
#       0 & 0 & 0 \\
#       0 & 0 & v \\
#       0 & 0 & 0
#   \end{bmatrix}
# $$
#
# and
#
# $$
#    B=\begin{bmatrix}
#     \frac{r}{2} & \frac{r}{2}  \\ 0 & 0 \\ -\frac{r}{\ell} & \frac{r}{\ell}
#   \end{bmatrix}
# $$

# %% [markdown]
# ##### 🧩 Is the system asymptotically stable, with $\Delta\omega(t)=0$?

# %% [markdown]
# 🔓 **Answer.** No since $A$ has 3 null eigenvalues.

# %% [markdown]
# ##### 🧩 Is the system attractive, with $\Delta\omega(t)=0$?

# %% [markdown]
# 🔓 **Answer.** No. Two possible justifications:
# 1. With an argument of the course: for linear system, locally attractive is equivalent to GAS. The system is not GAS (previous question).
# 2. By looking the system: e.g. the error $\Delta y$ remains constant without any input correction.

# %% [markdown]
# ##### 🧩 Show that the linearized system is controllable.

# %% [markdown]
# 🔓 **Answer.** We just study the rank of $C' = [B, AB]$ since $A^i=0$ for $i\geq2$
#
# $$C'=
# \begin{bmatrix}
#     \frac{r}{2} & \frac{r}{2} & 0 & 0 \\
#     0 & 0 & -v \frac{r}{\ell} & v \frac{r}{\ell} \\
#     -\frac{r}{2} & \frac{r}{2} & 0 & 0
# \end{bmatrix}
# $$
#
# The submatrix defined by keeping the 3 first columns if full rank. So, the controllability matrix is also full rank and the system is controllable.

# %% [markdown]
# ### Linearized system implementation

# %% [markdown]
# In the sequel, we will use $v=25 \mbox{ km/h}$.

# %% [markdown]
# ##### 🧩 Implement and print the matrices $A$ and $B$

# %%
v = 25 / 3.6
A = array([[0, 0, 0], [0, 0, v], [0, 0, 0]])
B = array([[r/2, r/2], [0, 0], [-r/l, r/l]])
print(A)
print(B)
# Out:
# [[0.         0.         0.        ]
#  [0.         0.         6.94444444]
#  [0.         0.         0.        ]]
# [[ 0.0625  0.0625]
#  [ 0.      0.    ]
#  [-0.25    0.25  ]]

# %% [markdown]
# The linear model has to be fed with some $\Delta\omega$ input. Like for the nonlinear system, we define a function $\Delta\omega(t,\Delta_X)$ that computes the input of the linearized system. For example, if we do not want any correction to the reference input, we set:

# %%
def deltaOmega(t, deltaX):
    return array([0, 0, 0])

# %% [markdown]
# ##### 🧩 Using this function `deltaOmega`, define a function `lin_fun` that computes $d{\Delta X}/dt$ given the arguments `t` and `deltaX`$.

# %%
# 🔓
def lin_fun(t, deltaX):
    return A @ deltaX + B @ deltaOmega(t, deltaX)

# %% [markdown]
# ### Controller Design on the linearized system

# %% [markdown]
# ##### 🧩 Implement a process that computes a gain matrix $K$ that places the poles of the linearized system at some arbitrary location.
#
# For this question, we will chose 3 real poles close to -1.0.
#
# Then, print the poles of the closed-loop system
#
# $$
# \frac{d\Delta X}{dt}= A \Delta X + B\Delta\omega
# \; \mbox{ with } \;
# \Delta\omega = -K \Delta X.
# $$

# %%
# 🔓
poles = [-1.0, -1.01, -1.02]  # Strictly negative real part
K = place_poles(A,B,poles).gain_matrix
print(K)
e,_ = eig(A - B @ K)
print(e)
# Out:
# [[ 8.07999995 -0.28665423 -3.99138351]
#  [ 8.07999999  0.30086577  4.08861651]]
# [-1.01+0.j -1.02+0.j -1.  +0.j]

# %% [markdown]
# ##### 🧩 Simulate the linearized system during 20s, with the initial condition $\Delta X(0) = (0,2,0)$.

# %%
def deltaOmega(t,deltaX):
    return -K @ deltaX

tf = 20
results = solve_ivp(
    fun=lin_fun, 
    t_span=[0, tf], 
    y0=[0, 2, 0], 
    dense_output=True, 
    rtol=1e-6, 
    atol=1e-6
)

# %% [markdown]
# 🧩 Plot the values of $\Delta x(t)$, $\Delta y(t)$ and $\Delta\theta(t)$ (**plot $\Delta\theta(t)$ in degrees**)

# %%
t = linspace(0.0, tf, 1000)
dx, dy, dtheta = results["sol"](t)
fig = figure(figsize=(12, 12))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label=r"$\Delta x(t)$")
ax1.plot(t, dy, label=r"$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$ deg")
ax2.legend()
None

# %% [markdown]
# ##### 🧩 Why is it important to check that $\Delta\theta(t)$ stays small ?

# %% [markdown]
# 🔓 **Answer.** The heading angle is the source of non linearity. To preserve the quality of the linearization, it is important that the error is small.

# %% [markdown]
# ##### 🧩 Compute the corresponding values of $\Delta\omega_l,\Delta\omega_r$ and store them in the Python variables `dOmega_l`, `dOmega_r`

# %%
dX = results["sol"](t)
dOmega = -K @ dX
dOmega_l = dOmega[0,:]
dOmega_r = dOmega[1,:]

# %% [markdown]
# ##### 🧩 Compute $\omega_l,\omega_r$ and plot the translation speed of each wheels in km/h

# %%
omega_l = dOmega_l + v/r
omega_r = dOmega_r + v/r
fig = figure(figsize=(12, 6))
plot(t, omega_l * r * 3.6, label=r"Left wheel speed (km/h)")
plot(t, omega_r * r * 3.6, label=r"Right wheel speed (km/h)")
grid()
legend()
pass

# %% [markdown]
# ##### 🧩 Are these control values consistent with what the robot should do to cancel the error?

# %% [markdown]
# 🔓 **Answer.** If there is not any error, the target speed of both wheels is 25 km/h. This is the value to which $\omega_l$ and $\omega_r$ seem to converge. At the beginning, the robot is a little bit too high ($y>0$), so it has to turn right. To do this, the left wheel has to be faster than the right one. This is effectively what we observes, and both values are around 25 km/h.

# %% [markdown]
# ###  Controller Tuning

# %% [markdown]
# ##### 🧩 Tune the poles (and recompute the gain matrix) so that the actual location $(x, y)$ is within 10 cm of the desired location within 20 sec but the angle $\Delta \theta$ never exceeds $\pm 5 \, \mathrm{deg}$. Plot the values of $\Delta x$ (in m), $\Delta y$ (in m), $\Delta \theta$ (in degrees), and the speed of each wheel (in km/h)

# %%
poles = [-0.6,-0.7,-0.8] # Strictly negative real part
K = place_poles(A,B,poles).gain_matrix

t2 = 20
sol = solve_ivp(fun=lin_fun,t_span=[0,t2],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

t = sol.t
dx, dy, dtheta = sol["sol"](t)

fig=figure(figsize=(12, 12))
ax1, ax2, ax3 = fig.subplots(3, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$")
ax2.legend()

dX = sol["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0]
dOmega_r = dOmega[1]
omega_l = dOmega_l +v/r
omega_r = dOmega_r +v/r

ax3.plot(t,omega_l*r*3.6, label=r"Left Wheel Speed (km/h)")
ax3.plot(t,omega_r*r*3.6, label=r"Right Wheel Speed (km/h)")
ax3.legend()
ax3.grid()

# %% [markdown]
# ##### 🧩 Simulate the initial, nonlinear scooter model when the control law computed in the section "Controller Tuning" is applied. Check that the constraint given for the control law design still hold.

# %%
def omega(t, xytheta):
    Xr = array([v*t,0,0])
    omegaR = array([v/r,v/r])
    deltaX = xytheta-Xr
    deltaOmega = -K@deltaX
    omega= omegaR + deltaOmega
    return omega

def scooter_nonlin(t, xytheta):
    omega_l, omega_r = omega(t, xytheta)
    x, y, theta = xytheta
    dx = r * 0.5 * (omega_l + omega_r) * cos(theta)
    dy = r * 0.5 * (omega_l + omega_r) * sin(theta)
    dtheta = r * (omega_r - omega_l) / l
    return array([dx, dy, dtheta])


y0 = [0, 2, 0] 
t2 = 20

sol = solve_ivp(fun=scooter_nonlin, t_span=[0, t2], y0=y0, dense_output=True, rtol=1e-6, atol=1e-12)

t = sol.t
solution = sol.sol(t)
dx, dy, dtheta = solution

fig = figure(figsize=(12, 12))
ax1, ax2, ax3 = fig.subplots(3, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label=r"$\Delta x(t)$")
ax1.plot(t, dy, label=r"$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta * 180 / pi, label=r"$\Delta \theta(t)$")
ax2.legend()
ax3.grid(True)

dOmega = array([omega(ti, solution[:, i]) for i, ti in enumerate(t)])
dOmega_l = dOmega[:, 0]
dOmega_r = dOmega[:, 1]

ax3.plot(t, dOmega_l * r * 3.6, label=r"Left Wheel Speed (km/h)")
ax3.plot(t, dOmega_r * r * 3.6, label=r"Right Wheel Speed (km/h)")
ax3.legend()
show()

# %% [markdown]
# ##### 🧩 Display the first 5 seconds of this trajectory using a snapshot of the scooter in the plane every 0.25 second.

# %%
step = 0.25
t = arange(0,5+step,step)
solution = sol["sol"](t)
draw_arena(-1, 40, -1, 5)
for x, y, theta in solution.T:
    draw_scooter(x, y, theta)

# %% [markdown]
# Step 3 - Optimal control, Global Control and General Trajectories
# =================================================================
#
#
# ###  Optimal control
#
# In this part we aim to design a stabilizing controller using an optimal control methodology.
#
# We still want to follow the reference trajectoy $x_R(t) = v t$ and $y_R(t) = 0$ where $v \in \mathbb{R}$ and $v \neq 0$ and will work with the linearized system
#
# $$
# \frac{d\Delta X}{dt}= A\Delta X + B\Delta\omega
# $$
#
# We want to find the control input $\Delta\omega$ that minimizes the quantity $J$ defined by
#
# $$
# J=\int_0^{t_f} q_1(\Delta x(t))^2 + q_2(\Delta y(t))^2 + q_3(\Delta \theta(t))^2+ r_1(\Delta \omega_l(t))^2+ r_2(\Delta \omega_r(t))^2 dt
# $$
#
# where the different constant $q_i$ and $r_i$ are strictly positive. We will denote
# $$
# Q=\begin{bmatrix}
#       q_1 & 0 & 0 \\
#       0 & q_2 & 0 \\
#       0 & 0 & q_3
#   \end{bmatrix}
# $$
# and
# $$
# R_0=\begin{bmatrix}
#       r_1 & 0 \\
#       0 & r_2 \\
#   \end{bmatrix}
# $$
#
# 🧩 Implement a function `Compute_cost` that computes the function $J$ for a given set of matrices $Q$ and $R$, a time horizon $t=[0,t_f]$, and for the corresponding functions $\Delta X$ and $\Delta \omega$ .
# To compute the integral, you can use the function `quad` (https://docs.scipy.org/doc/scipy/tutorial/integrate.html). You may need an intermediate function that returns the quantity
# $$
# q_1(\Delta x(t))^2 + q_2(\Delta y(t))^2 + q_3(\Delta \theta(t))^2+ r_1(\Delta \omega_l(t))^2+ r_2(\Delta \omega_r(t))^2
# $$

# %%
def Compute_cost (deltaX, deltaOmega, Q, R, t_horizon):
    def integrand(t):
        delta_x, delta_y, delta_theta = deltaX(t)
        domega_l, domega_r = deltaOmega(t)
        q1, q2, q3 = Q[0, 0], Q[1, 1], Q[2, 2]
        r1, r2 = R[0, 0], R[1, 1]

        return q1 * delta_x**2 + q2 * delta_y**2 + q3 * delta_theta**2 + r1 * domega_l**2 + r2 * domega_r**2
    
    t_f = t_horizon[-1]
    J, _ = quad(integrand, 0, t_f)
    return J

# %% [markdown]
# 🧩 Test the function `Compute_cost`  with the controller you designed in the Section 'Controller Tuning' when $q_i=1$ and $r_i=1$ ($t_f=20$).

# %%
simul = solve_ivp( fun=lin_fun, t_span=[0, 20], y0=[0, 2, 0], dense_output=True, rtol=1e-6, atol=1e-12)

def deltaX(t) :
    return simul["sol"](t)

def deltaOmega(t):
    return -K @ simul["sol"](t)

Q = array([[1,0,0],[0,1,0],[0,0,1]])
R_0 = array([[1,0],[0,1]])
t_hor = simul.t

cost = Compute_cost(deltaX, deltaOmega, Q, R_0, t_hor)
print(f"The computed cost is: {cost}")
# Out:
# The computed cost is: 7.330818905651259

# %% [markdown]
# 🧩 Multiply by 10 the poles and test the function `Compute_cost` in this new case. Interpret the results.

# %%
new_poles=[i*10 for i in poles]
K = place_poles(A,B,new_poles).gain_matrix

def deltaX(t) :
    return simul["sol"](t)

def deltaOmega(t):
    return -K @ simul["sol"](t)

Compute_cost(deltaX, deltaOmega, Q, R_0, t_hor)
# Out:
# 2359.220892360788

# %% [markdown]
# **Answer**
#
# Multiplying the pole by 10 effectively increases the value of $J$. This implies that the controller will now prioritize minimizing the deviations of the system from its desired trajectory more aggressively, leading to an increased control effort.

# %% [markdown]
# 🧩 Implement a process that computes a gain matrix $K$ that places the poles of the linearized system such that the quantity $J$ is minimum with "$t_f=+\infty$".
#
# Then, for $q_i=1$, $r_i=1$, print the poles of the closed-loop system:
#
# $$
# \frac{\Delta X}{dt}= A \Delta X + B\Delta\omega
# \; \text{ with } \;
# \Delta\omega = -K \Delta X.
# $$

# %%
def compute_gain_matrix(A, B, Q, R):
    P = solve_continuous_are(A, B, Q, R)
    K = linalg.inv(R) @ B.T @ P
    return K

K = compute_gain_matrix(A, B, Q, R_0)

def deltaOmega(t):
    return -K @ simul["sol"](t)

A_closed = A - B @ K
poles_closed, _ = eig(A_closed)
real_poles = [pole.real for pole in poles_closed]
imaginary_poles = [pole.imag for pole in poles_closed]

for real, imag in zip(real_poles, imaginary_poles):
    print(f"Pole: ({real}, {imag})")
# Out:
# Pole: (-1.1219919516467036, 1.0937851432342556)
# Pole: (-1.1219919516467036, -1.0937851432342556)
# Pole: (-0.08838834764831842, 0.0)

# %% [markdown]
# 🧩 Plot the values of $\Delta x$ (in m), $\Delta y$ (in m), $\Delta \theta$ (in degrees), and the speed of each wheel (in km/h). Compute the value of the cost for $t_f=20$. Compare with the control law you obtained by pole assignment. Intepret the results.

# %%
def deltaOmega(t,deltaX):
    return -K@deltaX

simul = solve_ivp(fun=lin_fun,t_span=[0, 20],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

t = linspace(0.0,tf, 1000)
dx, dy, dtheta = simul["sol"](t)
fig=figure(figsize=(12, 12))
ax1, ax2, ax3 = fig.subplots(3, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$")
ax2.legend()

dX = simul["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0]
dOmega_r = dOmega[1]
omega_l = dOmega_l + v/r
omega_r = dOmega_r + v/r

ax3.plot(t,omega_l*r*3.6, label="Left Wheel Speed (km/h)")
ax3.plot(t,omega_r*r*3.6, label="Right Wheel Speed (km/h)")
ax3.legend()
ax3.grid()

def delta_Omega(t):
    return -K@simul["sol"](t)

cost_20 = Compute_cost(deltaX, delta_Omega, Q, R_0, [0, 20])
print("Cost for t_f = 20:", cost_20)
# Out:
# Cost for t_f = 20: 3.6558414451754784

# %% [markdown]
# **Answer**
#
# We now obtain a cost of $3.6558$, significantly lower than  the control law obtained by pole assignment: $2828.6618$. Meaning the control system is effectively tracking the reference trajectories while minimizing control effort.

# %% [markdown]
# 🧩 Try large values of $Q$ then large values of $R$ and explain how these choices influence the control effort as well as the convergence speed. Do you think that both strategies will perform similarly when applied to the scooter nonlinear model? Then select $Q$ and $R$ to ensure that the scooter angle nevers exceeds 5 degrees and that $x$ and $y$ have less than 10 cm error after 20 sec.

# %%
# Large Q
Q_large = 100 * eye(3)

K = compute_gain_matrix(A, B, Q_large, R_0)

def deltaOmega(t,deltaX):
    return -K@deltaX

simul = solve_ivp(fun=lin_fun,t_span=[0, 20],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

t = linspace(0.0,tf, 1000)
dx, dy, dtheta = simul["sol"](t)
fig=figure(figsize=(12, 12))
ax1, ax2, ax3 = fig.subplots(3, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$")
ax2.legend()

dX = simul["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0]
dOmega_r = dOmega[1]
omega_l = dOmega_l + v/r
omega_r = dOmega_r + v/r

ax3.plot(t,omega_l*r*3.6, label="Left Wheel Speed (km/h)")
ax3.plot(t,omega_r*r*3.6, label="Right Wheel Speed (km/h)")
ax3.legend()
ax3.grid()

def delta_Omega(t):
    return -K@simul["sol"](t)

cost_Q = Compute_cost(deltaX, delta_Omega, Q_large, R_0, [0, 20])
print("Cost for large Q:", cost_Q)
# Out:
# Cost for large Q: 127.87165364554524

# %%
# Large R
R_large = 100 * eye(2)

K = compute_gain_matrix(A, B, Q, R_large)

def deltaOmega(t,deltaX):
    return -K@deltaX

simul = solve_ivp(fun=lin_fun,t_span=[0, 20],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

t = linspace(0.0,tf, 1000)
dx, dy, dtheta = simul["sol"](t)
fig=figure(figsize=(12, 12))
ax1, ax2, ax3 = fig.subplots(3, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$")
ax2.legend()

dX = simul["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0]
dOmega_r = dOmega[1]
omega_l = dOmega_l + v/r
omega_r = dOmega_r + v/r

ax3.plot(t,omega_l*r*3.6, label="Left Wheel Speed (km/h)")
ax3.plot(t,omega_r*r*3.6, label="Right Wheel Speed (km/h)")
ax3.legend()
ax3.grid()

def delta_Omega(t):
    return -K@simul["sol"](t)

cost_R = Compute_cost(deltaX, delta_Omega, Q, R_large, [0, 20])
print("Cost for large R:", cost_R)
# Out:
# Cost for large R: 11.430902807731023

# %% [markdown]
# **Answer**
#
# Large values of $Q$ prioritize minimizing tracking errors, potentially leading to faster convergence but higher control effort.
#
# Large values of $R$ prioritize minimizing control effort, potentially leading to slower convergence but lower control effort.
#
# We don't think the strategies will perform similarly when applied to the nonlinear model since each strategy prioritizes a different aspect.
#
# The latest example we provided (for $R = diag(100, 100)$ and $Q = diag(1, 1, 1)$) ensures that the scooter angle nevers exceeds 5 degrees and that $x$ and $y$ have less than 10 cm error after 20 sec.

# %% [markdown]
# ### Controller validation
#
# The goal of this part is to test the optimal controller once again the **true** (nonlinear) system.
#
# We are going to simulate the original `fun` function, but to do this, we need to define a new version of the function `omega` that computes the wheel velocities given `t` and `xytheta`.
#
# 🧩 Implement this new version of `omega`.

# %%
def omega(t, xytheta):
    Xr = array([v*t, 0, 0])
    dX = xytheta - Xr
    dOmega = -K@dX
    OmegaR = array([v/r]*2)
    return OmegaR + dOmega

# %% [markdown]
# ##### 🧩 Display the first 5 seconds of this trajectory using a snapshot of the scooter in the plane every 0.25 second.

# %%
step = 0.25
t = arange(0,5+step,step)

def scooter_nonlin(t, xytheta):
    omega_l, omega_r = omega(t, xytheta)
    x, y, theta = xytheta
    dx = r * 0.5 * (omega_l + omega_r) * cos(theta)
    dy = r * 0.5 * (omega_l + omega_r) * sin(theta)
    dtheta = r * (omega_r - omega_l) / l
    return array([dx, dy, dtheta])

sol = solve_ivp(fun=scooter_nonlin, t_span=[0, t2], y0=[0, 2, 0], dense_output=True, rtol=1e-6, atol=1e-6)

solution = sol["sol"](t)
draw_arena(-1, 40, -1, 5)

for x, y, theta in solution.T:
    draw_scooter(x, y, theta)

# %% [markdown]
# 🧩 Make a similar drawing but add to the scooter real location the scooter reference location in the background; use the blue color to represent this "virtual" scooter.

# %%
step = 0.25
t = arange(0,5+step,step)

def scooter_nonlin(t, xytheta):
    omega_l, omega_r = omega(t, xytheta)
    x, y, theta = xytheta
    dx = r * 0.5 * (omega_l + omega_r) * cos(theta)
    dy = r * 0.5 * (omega_l + omega_r) * sin(theta)
    dtheta = r * (omega_r - omega_l) / l
    return array([dx, dy, dtheta])

def draw_scooter(x, y, theta, color):
    translation = array([[x], [y]])
    rotation = array([
        [cos(theta), -sin(theta)], 
        [sin(theta),  cos(theta)]
    ])

    # Left pad
    corners = [[0, 0], [-r, l/2], [r, l/2]]
    corners += [corners[0]]
    corners = array(corners).T
    corners = rotation @ corners + translation
    xc = corners[0]
    yc = corners[1]
    fill(xc, yc, color=color, zorder=10)

    # Right pad
    corners = [[0, 0], [r, -l/2], [-r, -l/2]]
    corners += [corners[0]]
    corners = array(corners).T
    corners = rotation @ corners + translation
    xc = corners[0]
    yc = corners[1]
    fill(xc, yc, color=color, zorder=10)
    
    # Fixed Wheels
    wheel_left_xy_start = rotation @ [[-r], [-l/2]] + translation 
    wheel_left_xy_end = rotation @ [[r], [-l/2]] + translation
    plot([wheel_left_xy_start[0], wheel_left_xy_end[0]], [wheel_left_xy_start[1], wheel_left_xy_end[1]], color="black",linewidth=5, zorder=20)

    wheel_right_xy_start = rotation @ [[-r], [l/2]] + translation
    wheel_right_xy_end = rotation @ [[r], [l/2]] + translation
    plot([wheel_right_xy_start[0], wheel_right_xy_end[0]], [wheel_right_xy_start[1], wheel_right_xy_end[1]], color="black", linewidth=5, zorder=20)

    # Forward marker
    xm, ym = rotation @ array([0.5, 0]) + array([x, y])
    plot([xm], [ym], "o", color="green")

sol = solve_ivp(fun=scooter_nonlin, t_span=[0, t2], y0=[0, 2, 0], dense_output=True, rtol=1e-6, atol=1e-6)

solution = sol["sol"](t)
draw_arena(-1, 40, -1, 5)

for x, y, theta in solution.T:
    draw_scooter(x, y, theta, 'red')

Xr = array([v*t, zeros_like(t), zeros_like(t)])
for xr, yr, thetar in Xr.T:
    draw_scooter(xr, yr, thetar, color='blue')

# %% [markdown]
# 🧩 Show that a tuning with a large $Q$ may work with the linear approximation but will fail on the "real" (nonlinear) model.

# %%
# Linearized system function
def lin_fun(t, deltaX):
    return A @ deltaX + B @ deltaOmega(t, deltaX)

# Nonlinear system function
def scooter_nonlin(t, xytheta):
    omega_l, omega_r = omega(t, xytheta)
    x, y, theta = xytheta
    dx = r * 0.5 * (omega_l + omega_r) * cos(theta)
    dy = r * 0.5 * (omega_l + omega_r) * sin(theta)
    dtheta = r * (omega_r - omega_l) / l
    return array([dx, dy, dtheta])

# Define the desired trajectory function for both linear and nonlinear systems
def desired_trajectory(t):
    x_ref = 0 
    y_ref = 2 
    theta_ref = 0 
    return array([x_ref + v * t, y_ref * ones_like(t), theta_ref * ones_like(t)])

# Desired tolerances for angle and position errors
angle_tolerance = deg2rad(5) 
position_tolerance = 0.1 

K = compute_gain_matrix(A, B, Q_large, R_0) #Q= diag(100, 100, 100), R_0 = diag(1, 1)

# Define the function to compute Delta Omega
def deltaOmega(t, deltaX):
    return -K @ deltaX

# Simulate the linear system for 20 seconds
simul_linear = solve_ivp(fun=lin_fun, t_span=[0, 20], y0=[0, 2, 0], dense_output=True, rtol=1e-6, atol=1e-12)

# Simulate the nonlinear system for 20 seconds
simul_nonlinear = solve_ivp(fun=scooter_nonlin, t_span=[0, 20], y0=[0, 2, 0], dense_output=True, rtol=1e-6, atol=1e-12)

# Compute the trajectories for linear and nonlinear systems
linear_solution = simul_linear.sol
nonlinear_solution = simul_nonlinear.sol

# Plot trajectories
figure(figsize=(14, 10))

# Plot linear x and y
subplot(2, 2, 1)
plot(simul_linear.t, linear_solution(simul_linear.t)[0], label=r"Linear $\Delta x$")
plot(simul_linear.t, linear_solution(simul_linear.t)[1], label=r"Linear $\Delta y$")
xlabel('Time (s)')
ylabel('x, y')
legend()

# Plot nonlinear x and y
subplot(2, 2, 2)
plot(simul_nonlinear.t, nonlinear_solution(simul_nonlinear.t)[0], label=r"Nonlinear $\Delta x$")
plot(simul_nonlinear.t, nonlinear_solution(simul_nonlinear.t)[1], label=r"Nonlinear $\Delta y$")
xlabel('Time (s)')
ylabel('x, y')
legend()

# Plot linear theta
subplot(2, 2, 3)
plot(simul_linear.t, rad2deg(linear_solution(simul_linear.t)[2]), label=r'Linear $\Delta \theta$', color='g')
xlabel('Time (s)')
ylabel('Theta (degrees)')
legend()

# Plot nonlinear theta
subplot(2, 2, 4)
plot(simul_nonlinear.t, rad2deg(nonlinear_solution(simul_nonlinear.t)[2]), label=r'Nonlinear $\Delta \theta$', color='g')
xlabel('Time (s)')
ylabel('Theta (degrees)')
legend()

tight_layout()
show()

# Compute errors
linear_errors = abs(linear_solution(simul_linear.t) - desired_trajectory(simul_linear.t))
nonlinear_errors = abs(nonlinear_solution(simul_nonlinear.t) - desired_trajectory(simul_nonlinear.t))

# Compare against tolerances
angle_error_tolerance = deg2rad(5)
position_error_tolerance = 0.1

linear_angle_error = max(linear_errors[:, 2])
nonlinear_angle_error = max(nonlinear_errors[:, 2])

linear_position_error = max(linalg.norm(linear_errors[:, :2], axis=1))
nonlinear_position_error = max(linalg.norm(nonlinear_errors[:, :2], axis=1))

print(f"Linear System - Maximum Angle Error: {rad2deg(linear_angle_error)} degrees")
print(f"Nonlinear System - Maximum Angle Error: {rad2deg(nonlinear_angle_error)} degrees")

print(f"Linear System - Maximum Position Error: {linear_position_error} meters")
print(f"Nonlinear System - Maximum Position Error: {nonlinear_position_error} meters")
# Out:
# Linear System - Maximum Angle Error: 0.0006302494118437878 degrees
# Nonlinear System - Maximum Angle Error: 0.00044966233347474785 degrees
# Linear System - Maximum Position Error: 9.999989450025613e-07 meters
# Nonlinear System - Maximum Position Error: 7.134653925150501e-07 meters

# %% [markdown]
# ###  Marker Dynamics
#
# The person in the scooter now tries to control its vehicle by targetting only where should be the location of the green marker ($d=50$ cm in front of the scooter center) without any regard for the angle.

# %% [markdown]
# 🧩 Write the coordinates $(x_m, y_m)$ of this location as a function of $x$, $y$ and $\theta$.

# %% [markdown]
# **Answer**
#
# The coordinates $(x_m, y_m)$ of the location of the green marker (denoted by $m$) relative to the scooter's position (denoted by $s$) can be expressed as follows:
#
# $$
# x_m = x_s + d \cdot \cos(\theta)\\
# y_m = y_s + d \cdot \sin(\theta)
# $$

# %% [markdown]
# 🧩 Write the differential equation satisfied by $(x_m, y_m)$.

# %% [markdown]
# **Answer**
#
# The differential equations satisfied by the coordinates $(x_m, y_m)$ are as follows:
#
# $$
# \begin{align*}
# \dot{x_m} &= \dot{x_s} - d \cdot \dot{\theta} \cdot \sin(\theta) \\
# \dot{y_m} &= \dot{y_s} + d \cdot \dot{\theta} \cdot \cos(\theta)
# \end{align*}
# $$
#
# Substituting $\dot{x_s}$, $\dot{y_s}$ and $\dot{\theta}$ with their expressions, we get:
#
# $$
# \begin{align*}
# \dot{x}_m &= \frac{r}{2} (\omega_r + \omega_l) \cos(\theta) - d \cdot \frac{r}{l}(\omega_r - \omega_l) \sin(\theta) \\
# \dot{y}_m &= \frac{r}{2} (\omega_r + \omega_l) \sin(\theta) + d \cdot \frac{r}{l}(\omega_r - \omega_l) \cos(\theta)
# \end{align*}
# $$

# %% [markdown]
# 🧩 Show any (smooth) reference evolution of the marker $(x_f^m(t), y_f^m(t))$ and any initial state of the scooter consistent with the initial marker location, there is an admissible trajectory $(x(t), y(t), \theta(t))$ that corresponds to this reference.
#
# 🗝️ Hint: search the unique $\omega_l(t)$ and $\omega_r(t)$ – as functions of $\dot{x}_m^r(t)$, $\dot{y}_m^r(t)$ and $\theta(t)$ – that satisfies this property.

# %% [markdown]
# **Answer**
#
# To find the unique $\omega_l(t)$ and $\omega_r(t)$ that satisfy the given conditions, we need to consider the kinematic constraints of the scooter, particularly its ability to move and rotate. Let's derive these equations:
#
# Given:
# - $\dot{x}_m^r(t)$ and $\dot{y}_m^r(t)$ are the desired velocities of the marker along the x-axis and y-axis, respectively.
# - $\theta(t)$ is the angle of orientation of the scooter.
#
# We want to find $\omega_l(t)$ and $\omega_r(t)$ such that the marker moves according to the desired velocities.
#
# Using the previous expressions for $\dot{x}_m$ and $\dot{y}_m$, we can derive the following equations:
#
# $$
# \begin{align*}
# \dot{x}_m &= \dot{x}_s - d \cdot \dot{\theta} \cdot \sin(\theta) = \frac{r}{2} (\omega_r + \omega_l) \cos(\theta) - d \cdot \dot{\theta} \cdot \sin(\theta) \\
# \dot{y}_m &= \dot{y}_s + d \cdot \dot{\theta} \cdot \cos(\theta) = \frac{r}{2} (\omega_r + \omega_l) \sin(\theta) + d \cdot \dot{\theta} \cdot \cos(\theta)
# \end{align*}
# $$
#
# The equations for $\dot{x}_m$ and $\dot{y}_m$ in terms of $\omega_l$, $\omega_r$, $\theta$, and the scooter's parameters $r$ and $l$ are:
#
# $$
# \begin{align*}
# \dot{x}_m &= \frac{r}{2} (\omega_r + \omega_l) \cos(\theta) - d \cdot \frac{r}{l}(\omega_r - \omega_l) \sin(\theta) \\
# \dot{y}_m &= \frac{r}{2} (\omega_r + \omega_l) \sin(\theta) + d \cdot \frac{r}{l}(\omega_r - \omega_l) \cos(\theta)
# \end{align*}
# $$
#
# $$
# \dot{y}_m = r\frac{\omega_l + \omega_r}{2}\sin(\theta) + d \times r\frac{\omega_r - \omega_l}{l}\cos(\theta)
# $$
#
# Then:
#
# $$
# \omega_l + \omega_r = 2(\cos(\theta)\frac{\dot{x}_m^r}{r} + \sin(\theta)\frac{\dot{y}_m^r}{r})
# $$
#
# $$
# \omega_r - \omega_l = \frac{l}{d}(-\sin(\theta)\frac{\dot{x}_m^r}{r} + \cos(\theta)\frac{\dot{y}_m^r}{r})
# $$
#
# Thus:
#
# $$
# \omega_{l} = (\cos(\theta) \frac{\dot{x}_m^r}{r} + \sin(\theta) \frac{\dot{y}_m^{r}}{r}) + \frac{l}{2d}(-\sin(\theta)\frac{\dot{x}_m^r}{r}+\cos(\theta) \frac{\dot{y}_m^{r}}{r})
# $$
#
# $$
# \omega_{r} = (\cos(\theta) \frac{\dot{x}_m^{r}}{r} + \sin(\theta) \frac{\dot{y}_m^{r}}{r}) - \frac{l}{2d}(-\sin(\theta)\frac{\dot{x}_m^{r}}{r}+\cos(\theta) \frac{\dot{y}_m^{r}}{r})
# $$

# %% [markdown]
# 🧩 Let $v>0$ be the value in m/s that corresponds to $25$ km/h and let $(x_m^r(t), y_m^r(t)) = (vt, 0)$.
# Simulate the scooter evolution with the choice for $\omega_l$ and $\omega_r$ of the previous question for $X(0) = (-d, 0, 0)$. Represent the scooter every second with an extra dot for the marker location.
#
# Then, try the simulation with
# $$
# X(0) = (-d\cos(\alpha), -d\sin(\alpha), \alpha)
# $$
# for different values of $\alpha = \theta(0)$. In particular, investigate the case of à $\theta(0)$ close to $0$, then close to $\pi$). Is the system dynamics asymptotically stable in each case?

# %%
# Constants
v = 25 / 3.6  # Convert 25 km/h to m/s
d = 0.5  # Distance to the marker

# Define the omega function
def omega(t, xytheta):
    Xr = array([v * t, 0, 0])
    dX = xytheta - Xr
    dW = -K @ dX
    Wr = array([v / r, v / r])
    return Wr + dW

# Define the dynamics function
def fun(t, xytheta):
    omega_l, omega_r = omega(t, xytheta)
    dx = r * 0.5 * (omega_l + omega_r) * cos(xytheta[2])
    dy = r * 0.5 * (omega_l + omega_r) * sin(xytheta[2])
    dtheta = r * (omega_r - omega_l) / l
    return array([dx, dy, dtheta])

# Initial conditions
X0 = array([-d, 0, 0])

# Simulate the system
tf = 10
t_eval = linspace(0, tf, 1000)
sol = solve_ivp(fun, [0, tf], X0, t_eval=t_eval, dense_output=True,rtol=1e-6, atol=1e-12)

# Plot the results
fig, ax = subplots(figsize=(12, 8))
ax.set_aspect('equal', 'box')
ax.grid(True)
ax.set_xlabel('X (m)')
ax.set_ylabel('Y (m)')
draw_arena(-5, 30, -5, 5)

# Draw the scooter and marker every second
for i in range(0, len(sol.t), int(len(sol.t) / 10)):
    x, y, theta = sol.y[:, i]
    xm = x + d * cos(theta)
    ym = y + d * sin(theta)
    draw_scooter(x, y, theta, "red")
    ax.plot(xm, ym, 'go')  # Marker location

show()

# Test different initial conditions
alphas = [0, pi / 4, pi / 2, pi]

for alpha in alphas:
    X0 = array([-d * cos(alpha), -d * sin(alpha), alpha])
    sol = solve_ivp(fun, [0, tf], X0, t_eval=t_eval, rtol=1e-6, atol=1e-12)
    
    fig, ax = subplots(figsize=(12, 8))
    ax.set_aspect('equal', 'box')
    ax.grid(True)
    ax.set_xlabel('X (m)')
    ax.set_ylabel('Y (m)')
    draw_arena(-5, 30, -5, 5)
    
    for i in range(0, len(sol.t), int(len(sol.t) / 10)):
        x, y, theta = sol.y[:, i]
        xm = x + d * cos(theta)
        ym = y + d * sin(theta)
        draw_scooter(x, y, theta, "red")
        ax.plot(xm, ym, 'go')
    
    title(f"Initial Condition: alpha = {alpha}")
    show()

# %% [markdown]
# **Interpretation**
#
# The simulations with different initial conditions ($\alpha$) provide insight into the dynamic stability and trajectory-following capability of the system:
#
# 1. *Initial Condition $\alpha = 0$*: The scooter starts aligned with the trajectory and successfully follows it closely throughout, demonstrating that the system is stable when starting without angular displacement.
#
# 2. *Initial Condition $\alpha = 0.785$ (approximately $\pi/4$)*: The scooter begins with a moderate angular deviation. It starts off course but gradually attempts to align with the desired trajectory. This suggests that the system has some capability to correct moderate angular misalignments, although it takes some time and space to adjust.
#
# 3. *Initial Condition $\alpha = 1.571$ (approximately $\pi/2$)*: With a significant initial angular displacement, the scooter's path is markedly different from the intended trajectory at the start. However, it eventually aligns with the trajectory, indicating that the system can handle even larger errors, albeit less efficiently.
#
# 4. *Initial Condition $\alpha = 3.142$ (approximately $\pi$)*: The scooter starts facing the opposite direction. Despite this, it manages to turn around and align itself with the trajectory, which shows robustness in the control system but also highlights a potentially large initial correction cost in terms of path efficiency and time.
#
# The system dynamics are asymptotically stable in each of the two cases.

# %% [markdown]
# 🧩 Consider pillars (of small radius) whose centers are aligned and distant of 2 meters, say at the locations
# $$
# (1.0,0), (3.0, 0), (5.0,0), \mathrm{etc.}.
# $$
# Compute a reference trajectory trajectory that would lead the marker from $(0,0)$ to $(6,0)$ with a slalom between the pillars. Of course, you don't want the robot frame to bump into the pillars ! Display this trajectory graphically. What happens when if the inputs $\omega_l(t)$ and $\omega_r(t)$ are applied but the robot is not initially at the expected position ?

# %% [markdown]
# **Answer**
#
# The pillars are positioned at $(1,0), (3,0), (5,0)$.
#
# We'll create a smooth sinusoidal trajectory for the marker to navigate around the pillars:
#
# $$ x_m^r(t) = v \cdot t $$
#
# $$ y_m^r(t) = Am \cdot \sin \left( \frac{\pi x_m^r(t)}{L} \right) $$
#
# where $ Am $ is the amplitude of the sinusoidal path and $ L $ is the distance between the pillars (2 meters).

# %%
# Constants
v = 25 / 3.6  # Convert 25 km/h to m/s
r = 0.125  # Wheel radius
l = 0.5  # Distance between wheels
d = 0.5  # Distance to the marker
Am = 0.5  # Amplitude of the sinusoidal path
L = 2  # Distance between pillars

# Define the reference trajectory for the marker
def x_m_ref(t):
    return v * t

def y_m_ref(t):
    return Am * sin(pi * x_m_ref(t) / L)

# Compute the derivatives of the reference trajectory
def dx_m_ref(t):
    return v

def dy_m_ref(t):
    return Am * pi * v / L * cos(pi * x_m_ref(t) / L)

# Define the omega function
def omega(t, xytheta):
    theta = xytheta[2]
    dx_mr = dx_m_ref(t)
    dy_mr = dy_m_ref(t)
    omega_r = (cos(theta) * dx_mr + sin(theta) * dy_mr) / r
    omega_l = (cos(theta) * dx_mr + sin(theta) * dy_mr) / r - (l / (2 * d)) * (-sin(theta) * dx_mr + cos(theta) * dy_mr) / r
    return omega_l, omega_r

# Define the dynamics function
def fun(t, xytheta):
    omega_l, omega_r = omega(t, xytheta)
    dx = r * 0.5 * (omega_l + omega_r) * cos(xytheta[2])
    dy = r * 0.5 * (omega_l + omega_r) * sin(xytheta[2])
    dtheta = r * (omega_r - omega_l) / l
    return array([dx, dy, dtheta])

# Initial conditions
X0 = array([-d, 0, 0])

# Simulate the system
tf = 6 / v  # Time to reach x=6 at speed v
t_eval = linspace(0, tf, 1000)
sol = solve_ivp(fun, [0, tf], X0, t_eval=t_eval, rtol=1e-6, atol=1e-12)

# Plot the results
fig, ax = subplots(figsize=(12, 8))

ax.set_aspect('equal', 'box')
ax.grid(True)
ax.set_xlabel('X (m)')
ax.set_ylabel('Y (m)')

# Plot the pillars
pillar_positions = arange(1, 7, 2)
for x_pillar in pillar_positions:
    ax.plot(x_pillar, 0, 'ro', markersize=10)

# Plot the reference trajectory
t_ref = linspace(0, tf, 1000)
x_ref = x_m_ref(t_ref)
y_ref = y_m_ref(t_ref)
ax.plot(x_ref, y_ref, 'b--', label='Reference trajectory')

# Plot the robot trajectory
ax.plot(sol.y[0], sol.y[1], 'g-', label='Robot trajectory')

# Plot the scooter and marker every second
for i in range(0, len(sol.t), max(1, int(len(sol.t) // tf))):
    x, y, theta = sol.y[:, i]
    xm = x + d * cos(theta)
    ym = y + d * sin(theta)
    draw_scooter(x, y, theta, "red")
    ax.plot(xm, ym, 'go')

ax.legend()
show()

# Test different initial conditions
alphas = [0, pi / 4, pi / 2, pi]

for alpha in alphas:
    X0 = array([-d * cos(alpha), -d * sin(alpha), alpha])
    sol = solve_ivp(fun, [0, tf], X0, t_eval=t_eval, rtol=1e-6, atol=1e-12)
    
    fig, ax = subplots(figsize=(12, 8))
    ax.set_aspect('equal', 'box')
    ax.grid(True)
    ax.set_xlabel('X (m)')
    ax.set_ylabel('Y (m)')
    
    # Plot the pillars
    for x_pillar in pillar_positions:
        ax.plot(x_pillar, 0, 'ro', markersize=10)
    
    # Plot the reference trajectory
    ax.plot(x_ref, y_ref, 'b--', label='Reference trajectory')
    
    # Plot the robot trajectory
    ax.plot(sol.y[0], sol.y[1], 'g-', label='Robot trajectory')
    
    # Plot the scooter and marker every second
    for i in range(0, len(sol.t), max(1, int(len(sol.t) // tf))):
        x, y, theta = sol.y[:, i]
        xm = x + d * cos(theta)
        ym = y + d * sin(theta)
        
        draw_scooter(x, y, theta, "red")
        ax.plot(xm, ym, 'go')
    
    ax.legend()
    title(f"Initial Condition: alpha = {alpha}")
    show()

# %% [markdown]
# If the inputs $\omega_l(t)$ and $\omega_r(t)$ are applied, but the robot is not initially at the expected position, the trajectory followed by the robot may deviate from the desired reference trajectory. The extent of this deviation depends on the initial position and orientation of the robot relative to the reference trajectory. In general:
#
# 1. If the initial position and orientation of the robot are close to the reference trajectory, the deviation may be small, and the robot may gradually converge to the desired path as it follows the control inputs.
#
# 2. If the initial position and orientation of the robot are significantly different from the reference trajectory, the deviation may be larger, and the robot may exhibit oscillatory behavior or fail to converge to the desired path.
